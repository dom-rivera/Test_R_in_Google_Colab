# %% [markdown]
# <a href="https://colab.research.google.com/github/dom-rivera/Test_R_in_Google_Colab/blob/main/R_in_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test 1 - Running R in Google Colab

# %%
# Downloading packages in R
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#Test Code
ab <- 34
cd <- 55
results <- ab+cd
print(results)
# Out:
# [1] 89

# %%
#Test 1 Run Package - Data Visualization
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Test 1  Data Visualization in R
plot(cars + c(1,4,6,5,10), type = "o") + title(main = "Cars vs Index")
# Out:
# integer(0)
# Plot with title “Cars vs Index”

# %%
# Test 2  Data Visualization in R
ggplot(mtcars, aes(x = mpg, y = wt)) + geom_point()
# Out:
# plot without title

# %%
# Test 3 Adding titles to plot
ggplot(mtcars, aes(x = mpg, y = wt)) + geom_point() +
  ggtitle("Miles per gallon vs Weight") +
  labs(y = "weight", x = "Miles per gallon")
# Out:
# plot without title

# %% [markdown]
# # Getting started with RStudio and Installing packages

# %%
# Running data sets
library (datasets)
data(iris)
View(iris)
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# ...

# %%
#Specify a Data in R from a Data Set
unique(iris$Species)
# Out:
# [1] setosa     versicolor virginica
# Levels: setosa versicolor virginica

# %%
install.packages("GGally", repos = "https://cran.r-project.org", type = "source")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Rcpp’, ‘plyr’, ‘reshape’

# %% [markdown]
# # Add-ins
